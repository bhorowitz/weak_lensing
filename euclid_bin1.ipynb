# %%
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
from six.moves import cPickle as pickle

# %%
with open('euclid_bin1.dat', 'r') as f:
    bin1 = pickle.load(f)

# %%
bin1.shape
# Out:
# (27292883, 5)

# %%
hist(bin1[:,1])
# Out:
# (array([ 1087605.,  2893877.,  4021747.,  3299590.,  2452899.,  2366943.,
#          3956386.,  3702942.,  2532111.,   978783.]),
#  array([-83.35791779, -66.02412262, -48.69032745, -31.35653229,
#         -14.02273712,   3.31105804,  20.64485321,  37.97864838,
#          55.31244354,  72.64623871,  89.98003387]),
#  <a list of 10 Patch objects>)

# %%
print bin1[:,0].min(), bin1[:,0].max()
# Out:
# -3.44051718712 359.999969482

# %%
print bin1[:,1].min(), bin1[:,1].max()
# Out:
# -83.3579177856 89.9800338745

# %%
patch1 = bin1[(bin1[:,0] > 30) & (bin1[:,0] < 35) & (bin1[:,1] > 30) & (bin1[:,1] < 35)]

# %%
patch1.shape
# Out:
# (39737, 5)

# %%
plot(patch1[:,0], patch1[:,1], 'g.')

# %%
plot(bin1[:,0], bin1[:,1], 'g.')
